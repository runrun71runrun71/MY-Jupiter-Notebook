# %% [markdown]
# <h1>My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# <b>Rhonda L Robinson</b>
#     <br>Help Desk

# %% [markdown]
# *Data Science enables us to find meaningful patterrns and insights that can lead to better business management, which is essential for the business sector*

# %% [markdown]
# <h3>The code in Cell 5 will run python code and add the numbers 5 + 3 into a result of 8.

# %%
print (5+3)
# Out:
# 8

# %% [markdown]
# horizontal rule ___

# %% [markdown]
# | Column1 | Column2 | Column3 |
# | --- | --- | --- |
# | *first* | **second** | `third`|
# | 1 | 2 | 3 |

# %% [markdown]
# syntax highlighting

# %% [markdown]
# ```python
# s = "This is a Python string"
# print(s)
# ```

# %% [markdown]
# ~~strikethrough like this.~~
